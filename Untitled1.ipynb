# %% [markdown]
# <a href="https://colab.research.google.com/github/reshy94/beef/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# adding two plus two
# More lines....

2+2
# Out:
# 4

# %% [markdown]
# # big headrer
#
#
# ## small header
#
# ### smaller header

# %%
print ("Hello world")
# Out:
# Hello world

# %%
10*2
# Out:
# 20
